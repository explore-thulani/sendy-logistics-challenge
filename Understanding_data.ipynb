# %%
#import pandas
import pandas as pd
#import numpy
import numpy as np
#import pyplot
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Variable definition

# %%
definitions = pd.read_csv("VariableDefinitions.csv")

# %%
definitions.head(50)
# Out:
#                                      Order No  \
# 0                                     User Id
# 1                                Vehicle Type
# 2                               Platform Type
# 3                        Personal or Business
# 4                    Placement - Day of Month
# 5                Placement - Weekday (Mo = 1)
# 6                            Placement - Time
# 7                 Confirmation - Day of Month
# 8             Confirmation - Weekday (Mo = 1)
# 9                         Confirmation - Time
# 10           Arrival at Pickup - Day of Month
# 11       Arrival at Pickup - Weekday (Mo = 1)
# 12                   Arrival at Pickup - Time
# 13                      Pickup - Day of Month
# 14                  Pickup - Weekday (Mo = 1)
# 15                              Pickup - Time
# 16      Arrival at Destination - Day of Month
# 17  Arrival at Destination - Weekday (Mo = 1)
# 18              Arrival at Destination - Time
# 19                              Distance (KM)
# 20                                Temperature
# 21               Precipitation in millimeters
# 22                                 Pickup Lat
# 23                                Pickup Long
# 24                            Destination Lat
# 25                           Destination Long
# 26                                   Rider Id
# 27                Time from Pickup to Arrival
# 28                                        NaN
# 29                              Rider Metrics
# 30                                   Rider Id
# 31                               No_Of_Orders
# 32                                        Age
# 33                             Average_Rating
# 34                              No_of_Ratings
#
#                                                                                                                         Unique number identifying the order
# 0                                                                                                      Unique number identifying the customer on a platform
# 1                                                       For this competition limited to bikes, however in practice Sendy service extends to trucks and vans
# 2                                                                                                       Platform used to place the order, there are 4 types
# 3                                                                                                                                             Customer type
# 4                                                                                                                         Placement - Day of Month i.e 1-31
# 5                                                                                                                          Placement - Weekday (Monday = 1)
# 6                                                                                                       Placement - Time - Time of day the order was placed
# 7                                                                                                                      Confirmation - Day of Month i.e 1-31
# 8                                                                                                                       Confirmation - Weekday (Monday = 1)
# 9                                                                                      Confirmation - Time - Time of day the order was confirmed by a rider
# 10                                                                                                                Arrival at Pickup - Day of Month i.e 1-31
# 11                                                                                                                 Arrival at Pickup - Weekday (Monday = 1)
# 12                            Time of day the the rider arrived at the location to pick up the order - as marked by the rider through the Sendy application
# 13                                                                                                                           Pickup - Day of Month i.e 1-31
# 14                                                                                                                            Pickup - Weekday (Monday = 1)
# 15                                     Pickup - Time - Time of day the the rider picked up the order - as marked by the rider through the Sendy application
# 16                                                                                                              Arrival at Delivery - Day of Month i.e 1-31
# 17                                                                                                               Arrival at Delivery - Weekday (Monday = 1)
# 18  Arrival at Delivery Time - Time of day the rider arrived at the destination to deliver the order - as marked by the rider through the Sendy application
# 19                                                                                                                  The distance from Pickup to Destination
# 20                                                               Temperature at the time of order placement in Degrees Celsius (measured every three hours)
# 21                                                                                Precipitation at the time of order placement (measured every three hours)
# 22                                                                                                                             Latitude of pick up location
# 23                                                                                                                            Longitude of pick up location
# 24                                                                                                                            Latitude of delivery location
# 25                                                                                                                           Longitude of delivery location
# 26                                                                                                                   ID of the Rider who accepted the order
# 27                     Time in seconds between 'Pickup' and 'Arrival at Destination' - calculated from the columns for the purpose of facilitating the task
# 28                                                                                                                                                      NaN
# 29                                                                                                                                                      NaN
# 30                                                                                           Unique number identifying the rider (same as in order details)
# 31                                                                                                                 Number of Orders the rider has delivered
# 32                                                                                                 Number of days since the rider delivered the first order
# 33                                                                                                                              Average rating of the rider
# 34                                                                  Number of ratings the rider has received. Rating an order is optional for the customer.

# %% [markdown]
# # Riders Data

# %%
riders = pd.read_csv("Riders.csv")

# %%
riders.head()
# Out:
#        Rider Id  No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0  Rider_Id_396          2946  2298            14.0           1159
# 1  Rider_Id_479           360   951            13.5            176
# 2  Rider_Id_648          1746   821            14.3            466
# 3  Rider_Id_753           314   980            12.5             75
# 4  Rider_Id_335           536  1113            13.7            156

# %%
riders.shape
# Out:
# (960, 5)

# %%
riders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rider Id        960 non-null    object
#  1   No_Of_Orders    960 non-null    int64
#  2   Age             960 non-null    int64
#  3   Average_Rating  960 non-null    float64
#  4   No_of_Ratings   960 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 37.6+ KB

# %% [markdown]
# # Training data

# %%
training = pd.read_csv("Train.csv")

# %%
training.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1) Confirmation - Time  \
# 0                                5          9:40:10 AM
# 1                                5         11:23:21 AM
# 2                                2         12:42:44 PM
# 3                                5          9:26:05 AM
# 4                                1          9:56:18 AM
#
#    Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# 0                                 9                                     5
# 1                                12                                     5
# 2                                30                                     2
# 3                                15                                     5
# 4                                13                                     1
#
#   Arrival at Pickup - Time  Pickup - Day of Month  Pickup - Weekday (Mo = 1)  \
# 0              10:04:47 AM                      9                          5
# 1              11:40:22 AM                     12                          5
# 2              12:49:34 PM                     30                          2
# 3               9:37:56 AM                     15                          5
# 4              10:03:53 AM                     13                          1
#
#   Pickup - Time  Arrival at Destination - Day of Month  \
# 0   10:27:30 AM                                      9
# 1   11:44:09 AM                                     12
# 2   12:53:03 PM                                     30
# 3    9:43:06 AM                                     15
# 4   10:05:23 AM                                     13
#
#    Arrival at Destination - Weekday (Mo = 1) Arrival at Destination - Time  \
# 0                                          5                   10:39:55 AM
# 1                                          5                   12:17:22 PM
# 2                                          2                    1:00:38 PM
# 3                                          5                   10:05:27 AM
# 4                                          1                   10:25:37 AM
#
#    Distance (KM)  Temperature  Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                           NaN   -1.317755
# 1             16         26.4                           NaN   -1.351453
# 2              3          NaN                           NaN   -1.308284
# 3              9         19.2                           NaN   -1.281301
# 4              9         15.4                           NaN   -1.266597
#
#    Pickup Long  Destination Lat  Destination Long      Rider Id  \
# 0    36.830370        -1.300406         36.829741  Rider_Id_432
# 1    36.899315        -1.295004         36.814358  Rider_Id_856
# 2    36.843419        -1.300921         36.828195  Rider_Id_155
# 3    36.832396        -1.257147         36.795063  Rider_Id_855
# 4    36.792118        -1.295041         36.809817  Rider_Id_770
#
#    Time from Pickup to Arrival
# 0                          745
# 1                         1993
# 2                          455
# 3                         1341
# 4                         1214

# %%
training.drop(["User Id", "Order No","Vehicle Type"], axis = 1)
# Out:
#        Platform Type Personal or Business  Placement - Day of Month  \
# 0                  3             Business                         9
# 1                  3             Personal                        12
# 2                  3             Business                        30
# 3                  3             Business                        15
# 4                  1             Personal                        13
# ...              ...                  ...                       ...
# 21196              3             Personal                        20
# 21197              3             Business                        13
# 21198              3             Business                         7
# 21199              1             Personal                         4
# 21200              3             Business                        26
#
#        Placement - Weekday (Mo = 1) Placement - Time  \
# 0                                 5       9:35:46 AM
# 1                                 5      11:16:16 AM
# 2                                 2      12:39:25 PM
# 3                                 5       9:25:34 AM
# 4                                 1       9:55:18 AM
# ...                             ...              ...
# 21196                             3       3:54:38 PM
# 21197                             6      10:13:34 AM
# 21198                             4       5:06:16 PM
# 21199                             3       9:31:39 AM
# 21200                             2       2:19:47 PM
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                                9                                5
# 1                               12                                5
# 2                               30                                2
# 3                               15                                5
# 4                               13                                1
# ...                            ...                              ...
# 21196                           20                                3
# 21197                           13                                6
# 21198                            7                                4
# 21199                            4                                3
# 21200                           26                                2
#
#       Confirmation - Time  Arrival at Pickup - Day of Month  \
# 0              9:40:10 AM                                 9
# 1             11:23:21 AM                                12
# 2             12:42:44 PM                                30
# 3              9:26:05 AM                                15
# 4              9:56:18 AM                                13
# ...                   ...                               ...
# 21196          3:55:09 PM                                20
# 21197         10:13:41 AM                                13
# 21198          5:07:09 PM                                 7
# 21199          9:31:53 AM                                 4
# 21200          2:20:01 PM                                26
#
#        Arrival at Pickup - Weekday (Mo = 1) Arrival at Pickup - Time  \
# 0                                         5              10:04:47 AM
# 1                                         5              11:40:22 AM
# 2                                         2              12:49:34 PM
# 3                                         5               9:37:56 AM
# 4                                         1              10:03:53 AM
# ...                                     ...                      ...
# 21196                                     3               3:58:49 PM
# 21197                                     6              10:20:04 AM
# 21198                                     4               5:30:17 PM
# 21199                                     3               9:38:59 AM
# 21200                                     2               2:24:29 PM
#
#        Pickup - Day of Month  Pickup - Weekday (Mo = 1) Pickup - Time  \
# 0                          9                          5   10:27:30 AM
# 1                         12                          5   11:44:09 AM
# 2                         30                          2   12:53:03 PM
# 3                         15                          5    9:43:06 AM
# 4                         13                          1   10:05:23 AM
# ...                      ...                        ...           ...
# 21196                     20                          3    4:20:08 PM
# 21197                     13                          6   10:33:27 AM
# 21198                      7                          4    5:50:52 PM
# 21199                      4                          3    9:45:15 AM
# 21200                     26                          2    2:41:55 PM
#
#        Arrival at Destination - Day of Month  \
# 0                                          9
# 1                                         12
# 2                                         30
# 3                                         15
# 4                                         13
# ...                                      ...
# 21196                                     20
# 21197                                     13
# 21198                                      7
# 21199                                      4
# 21200                                     26
#
#        Arrival at Destination - Weekday (Mo = 1)  \
# 0                                              5
# 1                                              5
# 2                                              2
# 3                                              5
# 4                                              1
# ...                                          ...
# 21196                                          3
# 21197                                          6
# 21198                                          4
# 21199                                          3
# 21200                                          2
#
#       Arrival at Destination - Time  Distance (KM)  Temperature  \
# 0                       10:39:55 AM              4         20.4
# 1                       12:17:22 PM             16         26.4
# 2                        1:00:38 PM              3          NaN
# 3                       10:05:27 AM              9         19.2
# 4                       10:25:37 AM              9         15.4
# ...                             ...            ...          ...
# 21196                    4:20:17 PM              3         28.6
# 21197                   10:46:17 AM              7         26.0
# 21198                    6:40:05 PM             20         29.2
# 21199                   10:08:15 AM             13         15.0
# 21200                    3:17:23 PM             12         30.9
#
#        Precipitation in millimeters  Pickup Lat  Pickup Long  Destination Lat  \
# 0                               NaN   -1.317755    36.830370        -1.300406
# 1                               NaN   -1.351453    36.899315        -1.295004
# 2                               NaN   -1.308284    36.843419        -1.300921
# 3                               NaN   -1.281301    36.832396        -1.257147
# 4                               NaN   -1.266597    36.792118        -1.295041
# ...                             ...         ...          ...              ...
# 21196                           NaN   -1.258414    36.804800        -1.275285
# 21197                           NaN   -1.307143    36.825009        -1.331619
# 21198                           NaN   -1.286018    36.897534        -1.258414
# 21199                           NaN   -1.250030    36.874167        -1.279209
# 21200                           NaN   -1.255189    36.782203        -1.320157
#
#        Destination Long      Rider Id  Time from Pickup to Arrival
# 0             36.829741  Rider_Id_432                          745
# 1             36.814358  Rider_Id_856                         1993
# 2             36.828195  Rider_Id_155                          455
# 3             36.795063  Rider_Id_855                         1341
# 4             36.809817  Rider_Id_770                         1214
# ...                 ...           ...                          ...
# 21196         36.802702  Rider_Id_953                            9
# 21197         36.847976  Rider_Id_155                          770
# 21198         36.804800  Rider_Id_697                         2953
# 21199         36.794872  Rider_Id_347                         1380
# 21200         36.830887  Rider_Id_177                         2128
#
# [21201 rows x 26 columns]
